# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import datetime
import numpy as np
import os
import datetime
import pytz
import numpy.polynomial.polynomial as poly
# %matplotlib inline

# %% [markdown]
# # Reading in .csv files

# %%
df1 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CostalEnduranceOrgeonShelfSurfacePiercingProfilerMooringWinter.csv' )
df2 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CostalEnduranceOrgeonShelfSurfacePiercingProfilerMooringSummer.csv' )
df3 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CoastalEnduranceOregonOffshoreCabledShallowProfilerMooringWinter.csv' )
df4 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CoastalEnduranceOregonOffshoreCabledShallowProfilerMooringSummer.csv' )
df5 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CoastalEnduranceOregonOffshoreCabledDeepProfilerMooringWinter.csv' )
df6 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CoastalEnduranceOregonOffshoreCabledDeepProfilerMooringSummer.csv' )
df7 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayOregonSlopeBaseShallowProfilerWinter.csv' )
df8 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayOregonSlopeBaseShallowProfilerSummer.csv' )
df9 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayOregonSlopeBaseDeepProfilerMooringWinter.csv' )
df10 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayOregonSlopeBaseDeepProfilerMooringSummer.csv' )
df11 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayAxialBaseShallowProfilerWinter.csv' )
df12 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayAxialBaseShallowProfilerSummer.csv' )
df13 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayAxialBaseBaseDeepProfilerWinter.csv' )
df14 = pd.read_csv(r'C:\Users\neo_6\Downloads\450\CabledArrayAxialBaseBaseDeepProfilerSummer.csv' )

# %% [markdown]
# # Grabbing variables

# %%
depth1=df1.seawater_pressure
depth2=df2.seawater_pressure
depth3=df3.seawater_pressure
depth4=df4.seawater_pressure
depth5=df5.seawater_pressure
depth6=df6.seawater_pressure
depth7=df7.seawater_pressure
depth8=df8.seawater_pressure
depth9=df9.seawater_pressure
depth10=df10.seawater_pressure
depth11=df11.seawater_pressure
depth12=df12.seawater_pressure
depth13=df13.seawater_pressure
depth14=df14.seawater_pressure

T1=df1.seawater_temperature
T2=df2.seawater_temperature
T3=df3.seawater_temperature
T4=df4.seawater_temperature
T5=df5.seawater_temperature
T6=df6.seawater_temperature
T7=df7.seawater_temperature
T8=df8.seawater_temperature
T9=df9.seawater_temperature
T10=df10.seawater_temperature
T11=df11.seawater_temperature
T12=df12.seawater_temperature
T13=df13.seawater_temperature
T14=df14.seawater_temperature

S1=df1.practical_salinity
S2=df2.practical_salinity
S3=df3.practical_salinity
S4=df4.practical_salinity
S5=df5.practical_salinity
S6=df6.practical_salinity
S7=df7.practical_salinity
S8=df8.practical_salinity
S9=df9.practical_salinity
S10=df10.practical_salinity
S11=df11.practical_salinity
S12=df12.practical_salinity
S13=df13.practical_salinity
S14=df14.practical_salinity

# %% [markdown]
# # Calculating SOS

# %%
C1 = (1449.2 + 4.6*T1) - (0.055*(T1**2)) + ((0.00029)*(T1**3)) + ((1.34 - 0.01*T1))*( S1-35) + (0.016*depth1)
C2 = (1449.2 + 4.6*T2) - (0.055*(T2**2)) + ((0.00029)*(T2**3)) + ((1.34 - 0.01*T2))*( S2-35) + (0.016*depth2)
C3 = (1449.2 + 4.6*T3) - (0.055*(T3**2)) + ((0.00029)*(T3**3)) + ((1.34 - 0.01*T3))*( S3-35) + (0.016*depth3)
C4 = (1449.2 + 4.6*T4) - (0.055*(T4**2)) + ((0.00029)*(T4**3)) + ((1.34 - 0.01*T4))*( S4-35) + (0.016*depth4)
C5 = (1449.2 + 4.6*T5) - (0.055*(T5**2)) + ((0.00029)*(T5**3)) + ((1.34 - 0.01*T5))*( S5-35) + (0.016*depth5)
C6 = (1449.2 + 4.6*T6) - (0.055*(T6**2)) + ((0.00029)*(T6**3)) + ((1.34 - 0.01*T6))*( S6-35) + (0.016*depth6)
C7 = (1449.2 + 4.6*T7) - (0.055*(T7**2)) + ((0.00029)*(T7**3)) + ((1.34 - 0.01*T7))*( S7-35) + (0.016*depth7)
C8 = (1449.2 + 4.6*T8) - (0.055*(T8**2)) + ((0.00029)*(T8**3)) + ((1.34 - 0.01*T8))*( S8-35) + (0.016*depth8)
C9 = (1449.2 + 4.6*T9) - (0.055*(T9**2)) + ((0.00029)*(T9**3)) + ((1.34 - 0.01*T9))*( S9-35) + (0.016*depth9)
C10 = (1449.2 + 4.6*T10) - (0.055*(T10**2)) + ((0.00029)*(T10**3)) + ((1.34 - 0.01*T10))*( S10-35) + (0.016*depth10)
C11 = (1449.2 + 4.6*T11) - (0.055*(T11**2)) + ((0.00029)*(T11**3)) + ((1.34 - 0.01*T11))*( S11-35) + (0.016*depth11)
C12 = (1449.2 + 4.6*T12) - (0.055*(T12**2)) + ((0.00029)*(T12**3)) + ((1.34 - 0.01*T12))*( S12-35) + (0.016*depth12)
C13 = (1449.2 + 4.6*T13) - (0.055*(T13**2)) + ((0.00029)*(T13**3)) + ((1.34 - 0.01*T13))*( S13-35) + (0.016*depth13)
C14 = (1449.2 + 4.6*T14) - (0.055*(T14**2)) + ((0.00029)*(T14**3)) + ((1.34 - 0.01*T14))*( S14-35) + (0.016*depth14)

# %% [markdown]
# # Plotting

# %%
plt.title('Oregon Shelf Surface Piercing Profiler Mooring Winter')
plt.scatter(C1[0:len(C1):10],depth1[0:len(C1):10])
coef=np.polyfit(C1,depth1,2) #SSP average 
poly1d_fn=np.poly1d(coef)
plt.plot(C1,poly1d_fn(C1),'r-')
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Shelf Surface Piercing Profiler Mooring Summer')
plt.scatter(C2[0:len(C2):100],depth2[0:len(C2):100])
coef=np.polyfit(C2,depth2,4)
poly1d_fn=np.poly1d(coef)
plt.plot(C2,poly1d_fn(C2),'r-')
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Offshore Cabled Shallow Profiler Mooring Winter')
plt.scatter(C3[0:len(C3):100],depth3[0:len(C3):100])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Offshore Cabled Shallow Profiler Mooring Summer')
plt.scatter(C4[0:len(C4):500],depth4[0:len(C4):500])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Offshore Cabled Deep Profiler Mooring Winter')
plt.scatter(C5[0:len(C5):100],depth5[0:len(C5):100])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Offshore Cabled Deep Profiler Mooring Summer')
plt.scatter(C6[0:len(C6):10],depth6[0:len(C6):10])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('› Oregon Slope Base Shallow Profiler Winter')
plt.scatter(C7[0:len(C7):1000],depth7[0:len(C7):1000])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('› Oregon Slope Base Shallow Profiler Summer')
plt.scatter(C8[0:len(C8):500],depth8[0:len(C8):500])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Slope Base Deep Profiler Winter')
plt.scatter(C9[0:len(C9):10],depth9[0:len(C9):10])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Oregon Slope Base Deep Profiler Summer')
plt.scatter(C10[0:len(C10):10],depth10[0:len(C10):10])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Axial Base Shallow Profiler Winter')
plt.scatter(C11[0:len(C11):1000],depth11[0:len(C11):1000])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Axial Base Shallow Profiler Summer')
plt.scatter(C12[0:len(C12):500],depth12[0:len(C12):500])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Axial Base Deep Profiler Winter')
plt.scatter(C13[0:len(C13):10],depth13[0:len(C13):10])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')

# %%
plt.title('Axial Base Deep Profiler Summer')
plt.scatter(C14[0:len(C14):1000],depth14[0:len(C14):1000])
plt.ylabel('depth(m)')
plt.xlabel('SSP(m/s)')
# Out:
# Text(0.5, 0, 'SSP(m/s)')
